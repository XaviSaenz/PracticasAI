# %% [markdown]
# <a href="https://colab.research.google.com/github/XaviSaenz/PracticasAI/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tarea:
#
# Utilizando la pagina de kaggle, descargar una base de datos de interes y realizar un analisis inicial sencillo, revisando los tipos de datos de las columnas, sacar una descripcion general de los datos, revisar por valores nulos, y finalmente, utilizar la herramienta de matplotlib para representar los datos de manera grafica.

# %%
# Librerías para utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Cargar nuestra base de datos
datos_nfl = pd.read_csv("/content/drive/MyDrive/Maestria/Inteligencia Artificial/Datasets/Anime.csv")

# Cargar semilla para poder dar reproducibilidad (1)
np.random.seed(0)

#datos_nfl.head()
#datos_nfl.tail()

# %%
#Revisamos datos nulos por columna
valores_nulos = datos_nfl.isnull().sum()
valores_nulos[:5]

#Para verificar cuantas filas y columnas tiene nuestra base de datos.
print(datos_nfl.shape)


#Revisamos primero cuantos valores nulos en total tenemos
total_celdas = np.product(datos_nfl.shape)
total_nulos = valores_nulos.sum()

#Sacamos el porcentaje de valores perdidos.
total_nulos = (total_nulos/total_celdas) * 100
#print(total_nulos)

#eliminamos los valores nulos
renglones_Nan = datos_nfl.dropna()
renglones_Nan.head()

#Revisamos cuantos renglones teniamos originalmente y cuantas eliminamos.
#print("Numero de renglones en el dataset original: %d \n" % datos_nfl.shape[1])
#print("Numero de renglones eliminadas: %d" % renglones_Nan.shape[1])
# Out:
# (18495, 17)
#     Rank                                     Name  \
# 3      4         Fullmetal Alchemist: Brotherhood
# 7      8         Attack on Titan The Final Season
# 51    52    JoJo's Bizarre Adventure: Golden Wind
# 59    60  That Time I Got Reincarnated as a Slime
# 64    65     Code Geass: Lelouch of the Rebellion
#
#                                       Japanese_name   Type  Episodes  \
# 3    Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 7               Shingeki no Kyojin The Final Season  TV         16.0
# 51          JoJo no Kimyou na Bouken: Ougon no Kaze  TV         39.0
# 59                   Tensei Shitara Slime Datta Ken  TV         24.0
# 64                  Code Geass: Hangyaku no Lelouch  TV         25.0
#
#               Studio Release_season  \
# 3              Bones         Spring
# 7              MAPPA         Winter
# 51  David Production          Fall
# 59             8-Bit          Fall
# 64           Sunrise          Fall
#
#                                                  Tags  Rating  Release_year  \
# 3   Action, Adventure, Drama, Fantasy, Mystery, Sh...    4.58        2009.0
# 7   Action, Drama, Fantasy, Horror, Shounen, Dark ...    4.55        2020.0
# 51  Action, Adventure, Shounen, Europe, Italy, Sup...    4.43        2018.0
# 59  Action, Adventure, Comedy, Fantasy, Shounen, C...    4.39        2018.0
# 64  Mecha, Sci Fi, Conspiracy, Mind Games, Overpow...    4.38        2006.0
#
#     End_year                                        Description  \
# 3     2010.0  "The foundation of alchemy is based on the law...
# 7     2021.0  "It's been four years since the Scout Regiment...
# 51    2019.0  'Giorno Giovanna is a young man that lives in ...
# 59    2019.0  'Lonely thirty-seven-year-old Satoru Mikami is...
# 64    2007.0  'In 2010, the Britannian Empire enslaved Japan...
#
#                                       Content_Warning  \
# 3   Animal Abuse,, Mature Themes,, Violence,, Dome...
# 7   Explicit Violence,, Mature Themes,, Physical A...
# 51                       Animal Abuse,, Mature Themes
# 59                                           Violence
# 64                                  Nudity,, Violence
#
#                                         Related_Mange  \
# 3   Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 7                                     Attack on Titan
# 51  JoJo's Bizarre Adventure Part 1: Phantom Blood...
# 59  That Time I Got Reincarnated as a Slime (Light...
# 64  Code Geass: Lelouch of the Rebellion, Code Gea...
#
#                                         Related_anime  \
# 3   Fullmetal Alchemist: Brotherhood Specials, Ful...
# 7   Attack on Titan, Attack on Titan 2nd Season, A...
# 51  JoJo's Bizarre Adventure, JoJo's Bizarre Adven...
# 59  That Time I Got Reincarnated as a Slime: Veldo...
# 64  Code Geass: Dakkan no Z, Code Geass: Lelouch o...
#
#                                          Voice_actors  \
# 3   Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 7   Eren Jaeger : Yuuki Kaji, Armin Arlelt : Marin...
# 51  Bruno Bucciarati : Yuuichi Nakamura, Giorno Gi...
# 59  Rimuru Tempest : Takuma Terashima, Alice Rondo...
# 64  C.C. : Yukana, Kallen Stadtfeld : Ami Koshimiz...
#
#                                                 staff
# 3   Hiromu Arakawa : Original Creator, Yasuhiro Ir...
# 7   Hajime Isayama : Original Creator, Jun Shishid...
# 51  Hirohiko Araki : Original Creator, Naokatsu Ts...
# 59  Fuse : Original Creator, Mitz Vah : Original C...
# 64  Gorou Taniguchi : Director & Op Director & Ori...

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


# Cargar el conjunto de datos de Iris
#iris = load_iris()
target_names = datos_nfl["Rank"]
target_counts = datos_nfl["Episodes"]

# Graficar el gráfico de barras
plt.bar(target_names, target_counts)
plt.xlabel('Clases')
plt.ylabel('Número de muestras')
plt.title('Gráfico de Barras del Iris Dataset')
plt.show()
